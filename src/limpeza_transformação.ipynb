# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-855815be-883e-430a-bc64-7b5671b65e79" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-855815be-883e-430a-bc64-7b5671b65e79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('state_of_data_enriquecida.csv')
data.head(3)
# Out:
#    ('P1_a ', 'Idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                  31           Masculino                      Branca
# 1                  30           Masculino                      Branca
# 2                  37            Feminino                     Amarela
#
#    Média de horas com trabalho doméstico e cuidado de pessoas  \
# 0                                               16.5
# 1                                               16.5
# 2                                               17.0
#
#   ('P1_d ', 'PCD') ('P1_i ', 'Estado onde mora')  \
# 0              Não             Minas Gerais (MG)
# 1              Não           Espírito Santo (ES)
# 2              Não                São Paulo (SP)
#
#   ('P1_i_2 ', 'Regiao onde mora')  Roubos fora do domicílio por região  \
# 0                         Sudeste                                565.0
# 1                         Sudeste                                565.0
# ...

# %%
# Renomenando as colunas
data.rename(columns={
    "('P1_a ', 'Idade')": "Idade",
    "('P1_b ', 'Genero')": "Genero",
    "('P1_c ', 'Cor/raca/etnia')": "Cor",
    "Média de horas com trabalho doméstico e cuidado de pessoas": "Trabalho doméstico",
    "('P1_d ', 'PCD')": "PCD",
    "('P1_i ', 'Estado onde mora')": "Estado onde mora",
    "('P1_i_2 ', 'Regiao onde mora')": "Região onde mora",
    "('P1_l ', 'Nivel de Ensino')": "Nivel de ensino",
    "('P1_m ', 'Área de Formação')": "Área de formação",
    "('P2_a ', 'Qual sua situação atual de trabalho?')": "Situação atual de trabalho",
    "('P2_f ', 'Cargo Atual')": "Cargo atual",
    "('P2_g ', 'Nivel')": "Nivel",
    "('P2_h ', 'Faixa salarial')": "Faixa salarial",
    "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')": "Tempo de experiência em dados",
    "('P2_r ', 'Atualmente qual a sua forma de trabalho?')": "Forma de trabalho atual",
    "('P2_s ', 'Qual a forma de trabalho ideal para você?')": "Forma de trabalho ideal"}, inplace=True)

# %%
data.isna().sum()
# Out:
# Idade                                     0
# Genero                                    0
# Cor                                       0
# Trabalho doméstico                        0
# PCD                                       0
# Estado onde mora                        121
# Região onde mora                        124
# Roubos fora do domicílio por região     124
# Nivel de ensino                           0
# Área de formação                        113
# Situação atual de trabalho                0
# Cargo atual                            1436
# Nivel                                  1436
# Faixa salarial                          540
# Tempo de experiência em dados           540
# Forma de trabalho atual                 540
# Forma de trabalho ideal                 540
# dtype: int64

# %%
data["Roubos fora do domicílio por região"].fillna(0, inplace=True)
data["Trabalho doméstico"].fillna(0, inplace=True)
# Out:
# <ipython-input-22-cd5ee2bf3ffc>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Roubos fora do domicílio por região"].fillna(0, inplace=True)
# <ipython-input-22-cd5ee2bf3ffc>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.isna().sum()
# Out:
# Idade                                     0
# Genero                                    0
# Cor                                       0
# Trabalho doméstico                        0
# PCD                                       0
# Estado onde mora                        121
# Região onde mora                        124
# Roubos fora do domicílio por região       0
# Nivel de ensino                           0
# Área de formação                        113
# Situação atual de trabalho                0
# Cargo atual                            1436
# Nivel                                  1436
# Faixa salarial                          540
# Tempo de experiência em dados           540
# Forma de trabalho atual                 540
# Forma de trabalho ideal                 540
# dtype: int64

# %%
#Preenche todos os NA como não informado
data.fillna("Não informado", inplace=True)

# %%
data.to_csv("state_of_data_tratada.csv")
