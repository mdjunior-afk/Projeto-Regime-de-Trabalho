# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24aa4e9a-0931-4366-8b88-67ddd323284f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24aa4e9a-0931-4366-8b88-67ddd323284f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]

data = pd.read_csv(filename)
data.head()
# Out:
#    ('P1_a ', 'Idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                  31           Masculino                      Branca
# 1                  30           Masculino                      Branca
# 2                  37            Feminino                     Amarela
# 3                  22           Masculino                       Preta
# 4                  34           Masculino                      Branca
#
#    Média de horas com trabalho doméstico e cuidado de pessoas  \
# 0                                               16.5
# 1                                               16.5
# 2                                               17.0
# 3                                               17.1
# 4                                               16.5
#
#   ('P1_d ', 'PCD') ('P1_i ', 'Estado onde mora')  \
# 0              Não             Minas Gerais (MG)
# 1              Não           Espírito Santo (ES)
# 2              Não                São Paulo (SP)
# ...

# %% [markdown]
# ## Atualização dos atributos

# %%
data.rename(columns={"('P1_a ', 'Idade')": "Idade",
                     "('P1_b ', 'Genero')": "Genero",
                     "('P1_c ', 'Cor/raca/etnia')": "Cor/Raca",
                     "Média de horas com trabalho doméstico e cuidado de pessoas": "Trabalho domestico",
                     "('P1_d ', 'PCD')": "PCD",
                     "('P1_i ', 'Estado onde mora')": "Estado onde mora",
                     "('P1_i_2 ', 'Regiao onde mora')": "Região onde mora",
                     "Roubos fora do domicílio por região": "Roubos fora do domicilio",
                     "('P1_l ', 'Nivel de Ensino')": "Nivel de ensino",
                     "('P1_m ', 'Área de Formação')": "Area de formação",
                     "('P2_a ', 'Qual sua situação atual de trabalho?')": "Situação atual de trabalho",
                     "('P2_f ', 'Cargo Atual')": "Cargo atual",
                     "('P2_g ', 'Nivel')": "Nivel",
                     "('P2_h ', 'Faixa salarial')": "Faixa salarial",
                     "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')": "Tempo de experiencia",
                     "('P2_r ', 'Atualmente qual a sua forma de trabalho?')": "Forma de trabalho atual",
                     "('P2_s ', 'Qual a forma de trabalho ideal para você?')": "Forma de trabalho ideal"}, inplace=True)
data.head()
# Out:
#    Idade     Genero Cor/Raca  Trabalho domestico  PCD     Estado onde mora  \
# 0     31  Masculino   Branca                16.5  Não    Minas Gerais (MG)
# 1     30  Masculino   Branca                16.5  Não  Espírito Santo (ES)
# 2     37   Feminino  Amarela                17.0  Não       São Paulo (SP)
# 3     22  Masculino    Preta                17.1  Não       São Paulo (SP)
# 4     34  Masculino   Branca                16.5  Não    Minas Gerais (MG)
#
#   Região onde mora  Roubos de veículo  Roubos de carro  Roubos de moto  ...  \
# 0          Sudeste               92.0             67.0            25.0  ...
# 1          Sudeste               92.0             67.0            25.0  ...
# 2          Sudeste               92.0             67.0            25.0  ...
# 3          Sudeste               92.0             67.0            25.0  ...
# 4          Sudeste               92.0             67.0            25.0  ...
#
#    Roubos fora do domicilio         Nivel de ensino  \
# ...

# %% [markdown]
# ## Tratando valores NA

# %%
data.isna().sum()
# Out:
# Idade                            0
# Genero                           0
# Cor/Raca                         0
# Trabalho domestico               0
# PCD                              0
# Estado onde mora               121
# Região onde mora               124
# Roubos de veículo              124
# Roubos de carro                124
# Roubos de moto                 124
# Roubos de bicicleta            124
# Roubos fora do domicilio       124
# Nivel de ensino                  0
# Area de formação               113
# Situação atual de trabalho       0
# Cargo atual                   1436
# Nivel                         1436
# Faixa salarial                 540
# Tempo de experiencia           540
# Forma de trabalho atual        540
# Forma de trabalho ideal        540
# dtype: int64

# %% [markdown]
# ## Tratando valores NA de valores do tipo float

# %%
data["Roubos de veículo"].fillna(0, inplace=True)
data["Roubos de carro"].fillna(0, inplace=True)
data["Roubos de moto"].fillna(0, inplace=True)
data["Roubos de bicicleta"].fillna(0, inplace=True)
data["Roubos fora do domicilio"].fillna(0, inplace=True)
data.isna().sum()
# Out:
# <ipython-input-36-f6c167937db0>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Roubos de veículo"].fillna(0, inplace=True)
# <ipython-input-36-f6c167937db0>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Tratando os valores NA do tipo categorico

# %%
data.fillna("Não informado", inplace=True)
data.isna().sum()
# Out:
# Idade                         0
# Genero                        0
# Cor/Raca                      0
# Trabalho domestico            0
# PCD                           0
# Estado onde mora              0
# Região onde mora              0
# Roubos de veículo             0
# Roubos de carro               0
# Roubos de moto                0
# Roubos de bicicleta           0
# Roubos fora do domicilio      0
# Nivel de ensino               0
# Area de formação              0
# Situação atual de trabalho    0
# Cargo atual                   0
# Nivel                         0
# Faixa salarial                0
# Tempo de experiencia          0
# Forma de trabalho atual       0
# Forma de trabalho ideal       0
# dtype: int64

# %%
data.to_csv("state_of_data_tratada.csv")
